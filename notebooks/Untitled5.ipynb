# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
def NormalizeData(data:np.ndarray):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

x = np.array([1,2,3,4,5,6,7,8])
std_x = np.std(x)
mean_x = np.mean(x)
print(f"x: {x}, \nstd_x : {std_x}, mean_x :{mean_x}")

normal_x = NormalizeData(x)
std_normal_x = np.std(normal_x)
mean_normal_x = np.mean(normal_x)
print(f"normal_x: {normal_x}, \nstd_normal_x : {std_normal_x}, mean_x :{mean_normal_x}")
# Out:
# x: [1 2 3 4 5 6 7 8],
# std_x : 2.29128784747792, mean_x :4.5
# normal_x: [0.         0.14285714 0.28571429 0.42857143 0.57142857 0.71428571
#  0.85714286 1.        ],
# std_normal_x : 0.32732683535398854, mean_x :0.5

# %%
gau_x = norm.pdf(x, loc = mean_x, scale=std_x)
print(gau_x)
print(normal_x)
# Out:
# [0.05421925 0.09601118 0.14052944 0.17001611 0.17001611 0.14052944
#  0.09601118 0.05421925]
# [0.         0.14285714 0.28571429 0.42857143 0.57142857 0.71428571
#  0.85714286 1.        ]

# %%
plt.plot(gau_x)

# %%
plt.plot(gau_x_normal)

# %%
from scipy.stats import chi2
chi2.isf(0.05, 3)
# Out:
# 7.814727903251178
